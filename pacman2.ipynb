# %% [markdown]
# basics of DQN taken from: https://towardsdatascience.com/automating-pac-man-with-deep-q-learning-an-implementation-in-tensorflow-ca08e9891d9c

# %%
import numpy as np
import gym

# %%
import time
import IPython.display as ipd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from tqdm import tqdm
import gc
import copy
import pandas as pd
from time import time

# %matplotlib inline

# %%
import torch
from torch import nn

from torch.utils.data import Dataset, DataLoader
from torchvision.models import vgg16

from torch.optim import AdamW
from torch.optim.lr_scheduler import ReduceLROnPlateau

# %% [markdown]
# ### Functions

# %%
def preprocess_observation(obs):
    color = 54.
    # Crop and resize the image
    img = obs[1:176:2, ::2]
    # Convert the image to greyscale
    img = img.mean(axis=2)
    # Improve image contrast
    img[np.floor(img)==color] = 0
    # Next we normalize the image from -1 to +1
    img = (img - 128) / 128
    return torch.tensor(img.reshape(1, 1, 88, 80))

# %%
def choose_epsilon_greedy_action(state, dqn, epsilon=0.1, greedy=False, action_space_size=9):
    Qs = dqn(state).detach().numpy()
    if greedy or np.random.rand()>epsilon:
        action = np.argmax(Qs)
    else:
        action = np.random.randint(0, action_space_size)
        
    return action

# %%
def choose_epsilon_greedy_multiple_actions(states, dqn, epsilon=0.1, greedy=False, action_space_size=9):
    Qs = dqn(states).detach().numpy()
    if greedy:
        action = np.argmax(Qs)
    elif np.random.rand()>epsilon:
        action = np.argmax(Qs)
    else:
        action = np.random.randint(0, action_space_size)
        
    return action

# %%
def display_only_generated(generated, fps=30):
    fig = plt.figure()

    ims = []
    for frame in tqdm(generated):
        im = plt.imshow(frame, animated=True)
        plt.axis('off')
        ims.append([im])
    interval = 1000/fps
    ani = animation.ArtistAnimation(fig, ims, interval=interval, repeat_delay=1000)
    plt.close()
    return ani

# %%
def create_episode_video(dqn, greedy=True):
    observation = env.reset()

    l = []
    for i in range(1000):
        observation, reward, is_done, info = env.step(choose_epsilon_greedy_action(preprocess_observation(observation), dqn, greedy=greedy))

        l.append(observation)
        if is_done:
            break
            
    vid = display_only_generated(l, fps=10)
    
    return vid

# %%
class BufferDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, dqn, n_episodes, discount, verbose=True, epsilon=0.1):
        """
        Args:
            buffer (list): list of tuples, where each tuple is (state_t, action_t, reward_t1, state_t1, is_t1_terminal).
        """
        self.n_episodes = n_episodes
        self.dqn = copy.deepcopy(dqn)
        self.discount = discount
        self.verbose = verbose
        self.epsilon = epsilon
        
        self.buffer = self._create_buffer()
        
        self.S_ts = [i[0] for i in self.buffer]
        self.As = np.array([j[1] for j in self.buffer])
        self.Qs_t1 = self._get_Qs_t1()
        self.Qs_t1_max = self.Qs_t1.max(axis=1)[0]
        self.Rs_t1 = torch.tensor(np.array([i[2] for i in self.buffer]))
        self.are_terminal_t1s = torch.tensor(np.array([i[4] for i in self.buffer]))

        self.ys = self.Rs_t1 + self.discount*self.are_terminal_t1s*self.Qs_t1_max
        
        if verbose:
            print(f"len(buffer): {len(self.buffer)}")
            print(f"Qs_t1.shape: {self.Qs_t1.shape}")
            print(f"Qs_t1_max.shape: {self.Qs_t1_max.shape}")
            print(f"Rs_t1.shape: {self.Rs_t1.shape}")
            print(f"are_terminal_t1s.shape: {self.are_terminal_t1s.shape}")
            
            print(f"ys.shape: {self.ys.shape}")
    
    def _create_buffer(self):
        buffer = []
        episodes = 0

        for k in range(self.n_episodes):
            if self.verbose:
                print(f"start building buffer's episode # {episodes+1}...")
                
            cumulative_reward = 0.
                    
            state_t = preprocess_observation(env.reset())
            is_t1_terminal = False
            
            while is_t1_terminal==False:
                action_t = choose_epsilon_greedy_action(state_t, self.dqn, epsilon=self.epsilon)

                state_t1, reward_t1, is_t1_terminal, info = env.step(action_t)
                cumulative_reward += reward_t1
                state_t1 = preprocess_observation(state_t1)

                buffer.append((state_t[0], action_t, reward_t1, state_t1[0], is_t1_terminal))
                state_t = state_t1
            
                if is_t1_terminal:
                    if self.verbose:
                        print(f"finished building buffer's episode # {episodes+1}. buffer length: {len(buffer)} steps. cumulative_reward={cumulative_reward}")
                    episodes += 1
                    gc.collect()
                    
        return buffer

    def _get_Qs_t1(self, batch_size=64):
        i=0
        Qs_t1 = []
        k=3 # the index of state_t1 in buffer sample.
        while i*batch_size<len(self.buffer):
            if self.verbose and (i*batch_size)%1000==0:
                print(f"preprocess Qs_t1: passed buffer[{(1000*(i*batch_size)//1000)}]")
            states_t1 = torch.stack([i[k] for i in self.buffer[i*batch_size:(i+1)*batch_size]])
            Qs_t1.append(self.dqn(states_t1).detach())
            gc.collect()
            i+=1

        return torch.cat(Qs_t1)
    
    
    def __len__(self):
        return len(self.buffer)

    def __getitem__(self, idx):
        X = self.S_ts[idx]
        A = self.As[idx]
        Y = self.ys[idx]
        
        return X, A, Y

# %% [markdown]
# ### Initialization and Expoloration of env

# %%
env = gym.make("MsPacman-v0")

# %% [markdown]
# ### define model and run episode with the untrained model

# %%
vgg = vgg16(pretrained=False)
vgg.features = vgg.features[:5]
vgg.features[0] = nn.Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
vgg.classifier[0] = nn.Linear(in_features=3136, out_features=4096, bias=True)
vgg.classifier[6] = nn.Linear(in_features=4096, out_features=9, bias=True)
dqn = vgg.double()

# %% [raw]
# dqn

# %%
optimizer = AdamW(dqn.parameters(), lr=0.0001)
lr_reduce =  ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08, verbose=False)

# %%
vid = create_episode_video(dqn)
ipd.HTML(vid.to_html5_video())
# Out:
# 100%|██████████| 1000/1000 [00:01<00:00, 935.44it/s]

# %% [markdown]
# ### training

# %% [markdown]
# - play games with current policy
# - for each step store the following supervised data for the batch training: (s,a,r,s’,d)
# - (s,a,r,s’,d) = (state_t, action_t, reward_t1, s_t1, is_done)

# %% [markdown]
# ### dataset
#
# #### Elements:
# - creating buffer by playing current dqn for n episodes
# - dqn works on states_t resulting with (N, 9) tensor.
# - we choose the ones to be updated by the proper actions we chose during building the buffer. For this we create tensor of As (actions)
# - this will do for calculateing Q(s, a)
# - now we refer to create the targets for training. using the r_t1 + Discount\*Q(s_t1, a_t1). if t1 is terminal - take only R_t1.
# - for this we need to run the dqn on all states S_t1 (get (N, 9) tensor), and take the max value for each new state.
#
# - reminder: buffer entry is (state_t, action_t, reward_t1, state_t1, is_terminal_t1)

# %%
EPSILON = 0.05
DISCOUNT_FACTOR = 0.95
LEARNING_RATE = 0.001

N_EPOCHS = 30
N_EPISODES = 30
BATCH_SIZE = 64

# %% [raw]
# dataset = BufferDataset(dqn, n_episodes=N_EPISODES, discount=DISCOUNT_FACTOR)

# %% [raw]
# X, A, Y = next(iter(dataloader))
# print(X.shape, A.shape, Y.shape)
# A = torch.tensor(list(zip(torch.arange(len(A)), A)))
#
# loss = ((dqn(X)[list(zip(*A))] - Y)**2).mean()
#
# loss

# %%
def print_headline(mystr):
    print("\n============================================================")
    print(mystr)
    print("============================================================")

# %%
optimizer = AdamW(dqn.parameters(), lr=LEARNING_RATE)
# lr_reduce =  ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, threshold=0.0001, threshold_mode='rel', cooldown=0, min_lr=0, eps=1e-08, verbose=False)

for epoch in range(N_EPOCHS):
    print_headline(f"EPOCH {epoch + 1}; start building replay buffer.")
    tic = time()
    dataset = BufferDataset(dqn, n_episodes=N_EPISODES, discount=DISCOUNT_FACTOR, epsilon=EPSILON)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
    toc = time()
    print(f"time: {toc-tic:.1f}sec.")
    
    running_loss = 0.0
    print_headline(f"EPOCH {epoch + 1}; start running training.")
    for i_batch, (X, A, Y) in enumerate(dataloader):
        tic = time()
    #     print(X.shape, A.shape, Y.shape)
        optimizer.zero_grad()

        A = torch.tensor(list(zip(torch.arange(len(A)), A)))
        loss = ((dqn(X)[list(zip(*A))] - Y)**2).mean()

        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        if i_batch % 10 == 9:    # print every 2000 mini-batches
            toc = time()
            print(f"batch: {i_batch + 1}/{len(dataset)//BATCH_SIZE+1}; loss: {running_loss / 10}; time: {toc-tic:.1f}sec.")
            running_loss = 0.0
            tic = toc

print('Finished Training')
# Out:
# ============================================================
# EPOCH 1; start building replay buffer.
# ============================================================
# start building buffer's episode # 1...
# finished building buffer's episode # 1. buffer length: 587 steps. cumulative_reward=270.0
# start building buffer's episode # 2...
# finished building buffer's episode # 2. buffer length: 1221 steps. cumulative_reward=160.0
# start building buffer's episode # 3...
# finished building buffer's episode # 3. buffer length: 1789 steps. cumulative_reward=140.0
# start building buffer's episode # 4...
# finished building buffer's episode # 4. buffer length: 2212 steps. cumulative_reward=150.0
# start building buffer's episode # 5...
# finished building buffer's episode # 5. buffer length: 2764 steps. cumulative_reward=200.0
# start building buffer's episode # 6...
# finished building buffer's episode # 6. buffer length: 3403 steps. cumulative_reward=170.0
# start building buffer's episode # 7...
# finished building buffer's episode # 7. buffer length: 3906 steps. cumulative_reward=160.0
# start building buffer's episode # 8...
# finished building buffer's episode # 8. buffer length: 4543 steps. cumulative_reward=150.0
# start building buffer's episode # 9...
# finished building buffer's episode # 9. buffer length: 5173 steps. cumulative_reward=230.0
# start building buffer's episode # 10...
# finished building buffer's episode # 10. buffer length: 5659 steps. cumulative_reward=150.0
# start building buffer's episode # 11...
# finished building buffer's episode # 11. buffer length: 6163 steps. cumulative_reward=140.0
# start building buffer's episode # 12...
# finished building buffer's episode # 12. buffer length: 6801 steps. cumulative_reward=240.0
# start building buffer's episode # 13...
# finished building buffer's episode # 13. buffer length: 7384 steps. cumulative_reward=260.0
# start building buffer's episode # 14...
# finished building buffer's episode # 14. buffer length: 8070 steps. cumulative_reward=220.0
# start building buffer's episode # 15...
# finished building buffer's episode # 15. buffer length: 8561 steps. cumulative_reward=110.0
# start building buffer's episode # 16...
# finished building buffer's episode # 16. buffer length: 9169 steps. cumulative_reward=270.0
# start building buffer's episode # 17...
# finished building buffer's episode # 17. buffer length: 9817 steps. cumulative_reward=150.0
# start building buffer's episode # 18...
# finished building buffer's episode # 18. buffer length: 10303 steps. cumulative_reward=100.0
# start building buffer's episode # 19...
# finished building buffer's episode # 19. buffer length: 10985 steps. cumulative_reward=210.0
# start building buffer's episode # 20...
# finished building buffer's episode # 20. buffer length: 11606 steps. cumulative_reward=210.0
# start building buffer's episode # 21...
# finished building buffer's episode # 21. buffer length: 12220 steps. cumulative_reward=160.0
# start building buffer's episode # 22...
# finished building buffer's episode # 22. buffer length: 12893 steps. cumulative_reward=170.0
# start building buffer's episode # 23...
# finished building buffer's episode # 23. buffer length: 13653 steps. cumulative_reward=410.0
# start building buffer's episode # 24...
# finished building buffer's episode # 24. buffer length: 14152 steps. cumulative_reward=160.0
# start building buffer's episode # 25...
# finished building buffer's episode # 25. buffer length: 14732 steps. cumulative_reward=300.0
# start building buffer's episode # 26...
# finished building buffer's episode # 26. buffer length: 15422 steps. cumulative_reward=150.0
# start building buffer's episode # 27...
# finished building buffer's episode # 27. buffer length: 16014 steps. cumulative_reward=260.0
# start building buffer's episode # 28...
# finished building buffer's episode # 28. buffer length: 16775 steps. cumulative_reward=280.0
# start building buffer's episode # 29...
# finished building buffer's episode # 29. buffer length: 17325 steps. cumulative_reward=130.0
# start building buffer's episode # 30...
# finished building buffer's episode # 30. buffer length: 17823 steps. cumulative_reward=140.0
# preprocess Qs_t1: passed buffer[0]
# preprocess Qs_t1: passed buffer[8000]
# preprocess Qs_t1: passed buffer[16000]
# len(buffer): 17823
# Qs_t1.shape: torch.Size([17823, 9])
# Qs_t1_max.shape: torch.Size([17823])
# Rs_t1.shape: torch.Size([17823])
# are_terminal_t1s.shape: torch.Size([17823])
# ys.shape: torch.Size([17823])
# time: 991.8sec.
#
# ============================================================
# EPOCH 1; start running training.
# ============================================================
# batch: 10/279; loss: 5.373495664325974; time: 5.0sec.
# batch: 20/279; loss: 3.255002940155226; time: 6.1sec.
# batch: 30/279; loss: 3.750875978391167; time: 4.6sec.
# batch: 40/279; loss: 1.738348303352436; time: 4.5sec.
# batch: 50/279; loss: 3.871747825189189; time: 4.7sec.
# batch: 60/279; loss: 2.7723320582540616; time: 4.7sec.
# batch: 70/279; loss: 2.8968642366686885; time: 4.6sec.
# batch: 80/279; loss: 2.0094508382410305; time: 4.6sec.
# batch: 90/279; loss: 3.987194345286187; time: 4.7sec.
# batch: 100/279; loss: 2.600060797501409; time: 4.6sec.
# batch: 110/279; loss: 3.4928317166640435; time: 4.9sec.
# batch: 120/279; loss: 2.2923791532303013; time: 4.7sec.
# batch: 130/279; loss: 3.7390236696227532; time: 4.7sec.
# batch: 140/279; loss: 3.6615202268274962; time: 4.8sec.
# batch: 150/279; loss: 3.493169500798392; time: 4.8sec.
# batch: 160/279; loss: 2.889950194632327; time: 4.7sec.
# batch: 170/279; loss: 3.607092144617148; time: 4.7sec.
# batch: 180/279; loss: 2.7586740603741218; time: 4.6sec.
# batch: 190/279; loss: 3.755527823826032; time: 4.7sec.
# batch: 200/279; loss: 3.624225793388161; time: 4.6sec.
# batch: 210/279; loss: 3.9075542391080846; time: 4.7sec.
# batch: 220/279; loss: 3.0322812242193136; time: 4.9sec.
# batch: 230/279; loss: 2.452651254174172; time: 4.9sec.
# batch: 240/279; loss: 2.5753328940707676; time: 4.8sec.
# batch: 250/279; loss: 3.726459851258982; time: 4.6sec.
# batch: 260/279; loss: 3.8472634798931096; time: 4.8sec.
# batch: 270/279; loss: 3.18314361549796; time: 4.6sec.
#
# ============================================================
# EPOCH 2; start building replay buffer.
# ============================================================
# start building buffer's episode # 1...
# finished building buffer's episode # 1. buffer length: 785 steps. cumulative_reward=1010.0
# start building buffer's episode # 2...
# finished building buffer's episode # 2. buffer length: 1679 steps. cumulative_reward=1150.0
# start building buffer's episode # 3...
# finished building buffer's episode # 3. buffer length: 2642 steps. cumulative_reward=670.0
# start building buffer's episode # 4...
# finished building buffer's episode # 4. buffer length: 3300 steps. cumulative_reward=520.0
# start building buffer's episode # 5...
# finished building buffer's episode # 5. buffer length: 4117 steps. cumulative_reward=640.0
# start building buffer's episode # 6...
# finished building buffer's episode # 6. buffer length: 4811 steps. cumulative_reward=610.0
# start building buffer's episode # 7...
# finished building buffer's episode # 7. buffer length: 5663 steps. cumulative_reward=1650.0
# start building buffer's episode # 8...
# finished building buffer's episode # 8. buffer length: 6358 steps. cumulative_reward=360.0
# start building buffer's episode # 9...
# finished building buffer's episode # 9. buffer length: 6997 steps. cumulative_reward=390.0
# start building buffer's episode # 10...
# finished building buffer's episode # 10. buffer length: 7635 steps. cumulative_reward=1000.0
# start building buffer's episode # 11...
# finished building buffer's episode # 11. buffer length: 8634 steps. cumulative_reward=560.0
# start building buffer's episode # 12...
# finished building buffer's episode # 12. buffer length: 9151 steps. cumulative_reward=410.0
# start building buffer's episode # 13...
# finished building buffer's episode # 13. buffer length: 9922 steps. cumulative_reward=500.0
# start building buffer's episode # 14...
# finished building buffer's episode # 14. buffer length: 10686 steps. cumulative_reward=980.0
# start building buffer's episode # 15...
# finished building buffer's episode # 15. buffer length: 11221 steps. cumulative_reward=280.0
# start building buffer's episode # 16...
# finished building buffer's episode # 16. buffer length: 11908 steps. cumulative_reward=320.0
# start building buffer's episode # 17...
# finished building buffer's episode # 17. buffer length: 12578 steps. cumulative_reward=360.0
# start building buffer's episode # 18...
# finished building buffer's episode # 18. buffer length: 13066 steps. cumulative_reward=350.0
# start building buffer's episode # 19...
# finished building buffer's episode # 19. buffer length: 13625 steps. cumulative_reward=540.0
# start building buffer's episode # 20...
# finished building buffer's episode # 20. buffer length: 14082 steps. cumulative_reward=360.0
# start building buffer's episode # 21...
# finished building buffer's episode # 21. buffer length: 14800 steps. cumulative_reward=400.0
# start building buffer's episode # 22...
# finished building buffer's episode # 22. buffer length: 15577 steps. cumulative_reward=530.0
# start building buffer's episode # 23...
# finished building buffer's episode # 23. buffer length: 16193 steps. cumulative_reward=450.0
# start building buffer's episode # 24...
# finished building buffer's episode # 24. buffer length: 16933 steps. cumulative_reward=770.0
# start building buffer's episode # 25...
# finished building buffer's episode # 25. buffer length: 17473 steps. cumulative_reward=300.0
# start building buffer's episode # 26...
# finished building buffer's episode # 26. buffer length: 18242 steps. cumulative_reward=710.0
# start building buffer's episode # 27...
# finished building buffer's episode # 27. buffer length: 19069 steps. cumulative_reward=480.0
# start building buffer's episode # 28...
# finished building buffer's episode # 28. buffer length: 19723 steps. cumulative_reward=200.0
# start building buffer's episode # 29...
# finished building buffer's episode # 29. buffer length: 20541 steps. cumulative_reward=450.0
# start building buffer's episode # 30...
# finished building buffer's episode # 30. buffer length: 21233 steps. cumulative_reward=470.0
# preprocess Qs_t1: passed buffer[0]
# preprocess Qs_t1: passed buffer[8000]
# preprocess Qs_t1: passed buffer[16000]
# len(buffer): 21233
# Qs_t1.shape: torch.Size([21233, 9])
# Qs_t1_max.shape: torch.Size([21233])
# Rs_t1.shape: torch.Size([21233])
# are_terminal_t1s.shape: torch.Size([21233])
# ys.shape: torch.Size([21233])
# time: 1121.2sec.
#
# ============================================================
# EPOCH 2; start running training.
# ============================================================
# batch: 10/332; loss: 129.06454222439746; time: 4.7sec.
# batch: 20/332; loss: 4.123055370905818; time: 4.8sec.
# batch: 30/332; loss: 67.38422440879613; time: 4.8sec.
# batch: 40/332; loss: 6.0188255177860235; time: 4.9sec.
# batch: 50/332; loss: 67.06941114642144; time: 4.7sec.
# batch: 60/332; loss: 8.955752848250894; time: 4.6sec.
# batch: 70/332; loss: 258.7632755942147; time: 4.6sec.
# batch: 80/332; loss: 67.04252764650697; time: 4.8sec.
# batch: 90/332; loss: 74.36845211903156; time: 4.7sec.
# batch: 100/332; loss: 4.212932327566149; time: 4.8sec.
# batch: 110/332; loss: 5.91080092793991; time: 4.7sec.
# batch: 120/332; loss: 4.660258779047245; time: 4.8sec.
# batch: 130/332; loss: 13.929317251620011; time: 4.6sec.
# batch: 140/332; loss: 12.741541270302944; time: 4.7sec.
# batch: 150/332; loss: 7.174693031125169; time: 4.8sec.
# batch: 160/332; loss: 70.73833650473975; time: 4.7sec.
# batch: 170/332; loss: 8.781380384632607; time: 4.9sec.
# batch: 180/332; loss: 253.15764708802743; time: 4.8sec.
# batch: 190/332; loss: 335.0242408331752; time: 4.6sec.
# batch: 200/332; loss: 253.51219160999236; time: 4.6sec.
# batch: 210/332; loss: 9.936467573582455; time: 5.2sec.
# batch: 220/332; loss: 5.800292403856952; time: 4.9sec.
# batch: 230/332; loss: 66.34695131532942; time: 4.7sec.
# batch: 240/332; loss: 4.720281916886473; time: 4.7sec.
# batch: 250/332; loss: 8.460270000594159; time: 4.7sec.
# batch: 260/332; loss: 68.62784650445487; time: 4.7sec.
# batch: 270/332; loss: 5.7870688155090475; time: 4.7sec.
# batch: 280/332; loss: 5.260481183332978; time: 4.7sec.
# batch: 290/332; loss: 70.40877157912522; time: 4.9sec.
# batch: 300/332; loss: 5.6763877832302425; time: 4.7sec.
# batch: 310/332; loss: 260.9159082853273; time: 4.7sec.
# batch: 320/332; loss: 7.9330841345156955; time: 4.7sec.
# batch: 330/332; loss: 1069.4675492928839; time: 4.7sec.
#
# ============================================================
# EPOCH 3; start building replay buffer.
# ============================================================
# start building buffer's episode # 1...
# finished building buffer's episode # 1. buffer length: 671 steps. cumulative_reward=320.0
# start building buffer's episode # 2...
# finished building buffer's episode # 2. buffer length: 1371 steps. cumulative_reward=300.0
# start building buffer's episode # 3...
# finished building buffer's episode # 3. buffer length: 2263 steps. cumulative_reward=260.0
# start building buffer's episode # 4...
# finished building buffer's episode # 4. buffer length: 3243 steps. cumulative_reward=460.0
# start building buffer's episode # 5...
# finished building buffer's episode # 5. buffer length: 4338 steps. cumulative_reward=300.0
# start building buffer's episode # 6...
# finished building buffer's episode # 6. buffer length: 5136 steps. cumulative_reward=410.0
# start building buffer's episode # 7...
# finished building buffer's episode # 7. buffer length: 5969 steps. cumulative_reward=550.0
# start building buffer's episode # 8...
# finished building buffer's episode # 8. buffer length: 6871 steps. cumulative_reward=1660.0
# start building buffer's episode # 9...
# finished building buffer's episode # 9. buffer length: 7858 steps. cumulative_reward=320.0
# start building buffer's episode # 10...
# finished building buffer's episode # 10. buffer length: 8604 steps. cumulative_reward=350.0
# start building buffer's episode # 11...
# finished building buffer's episode # 11. buffer length: 9295 steps. cumulative_reward=410.0
# start building buffer's episode # 12...
# finished building buffer's episode # 12. buffer length: 9940 steps. cumulative_reward=310.0
# start building buffer's episode # 13...
# finished building buffer's episode # 13. buffer length: 10735 steps. cumulative_reward=270.0
# start building buffer's episode # 14...
# finished building buffer's episode # 14. buffer length: 11567 steps. cumulative_reward=240.0
# start building buffer's episode # 15...
# finished building buffer's episode # 15. buffer length: 12445 steps. cumulative_reward=230.0
# start building buffer's episode # 16...
# finished building buffer's episode # 16. buffer length: 13556 steps. cumulative_reward=300.0
# start building buffer's episode # 17...
# finished building buffer's episode # 17. buffer length: 14442 steps. cumulative_reward=470.0
# start building buffer's episode # 18...
# finished building buffer's episode # 18. buffer length: 15208 steps. cumulative_reward=500.0
# start building buffer's episode # 19...
# finished building buffer's episode # 19. buffer length: 15807 steps. cumulative_reward=250.0
# start building buffer's episode # 20...
# finished building buffer's episode # 20. buffer length: 16596 steps. cumulative_reward=900.0
# start building buffer's episode # 21...
# finished building buffer's episode # 21. buffer length: 17904 steps. cumulative_reward=510.0
# start building buffer's episode # 22...
# finished building buffer's episode # 22. buffer length: 18704 steps. cumulative_reward=1800.0
# start building buffer's episode # 23...
# finished building buffer's episode # 23. buffer length: 19713 steps. cumulative_reward=260.0
# start building buffer's episode # 24...
# finished building buffer's episode # 24. buffer length: 20722 steps. cumulative_reward=930.0
# start building buffer's episode # 25...
# finished building buffer's episode # 25. buffer length: 21416 steps. cumulative_reward=430.0
# start building buffer's episode # 26...
# finished building buffer's episode # 26. buffer length: 22202 steps. cumulative_reward=300.0
# start building buffer's episode # 27...
# finished building buffer's episode # 27. buffer length: 23132 steps. cumulative_reward=910.0
# start building buffer's episode # 28...
# finished building buffer's episode # 28. buffer length: 24161 steps. cumulative_reward=420.0
# start building buffer's episode # 29...
# finished building buffer's episode # 29. buffer length: 24866 steps. cumulative_reward=230.0
# start building buffer's episode # 30...
# finished building buffer's episode # 30. buffer length: 25697 steps. cumulative_reward=1670.0
# preprocess Qs_t1: passed buffer[0]
# preprocess Qs_t1: passed buffer[8000]
# preprocess Qs_t1: passed buffer[16000]
# preprocess Qs_t1: passed buffer[24000]
# len(buffer): 25697
# Qs_t1.shape: torch.Size([25697, 9])
# Qs_t1_max.shape: torch.Size([25697])
# Rs_t1.shape: torch.Size([25697])
# are_terminal_t1s.shape: torch.Size([25697])
# ys.shape: torch.Size([25697])
# time: 1311.7sec.
#
# ============================================================
# EPOCH 3; start running training.
# ============================================================
# batch: 10/402; loss: 2.913274350514569; time: 4.6sec.
# batch: 20/402; loss: 6.857029627846541; time: 4.5sec.
# batch: 30/402; loss: 3.085185403152073; time: 4.5sec.
# batch: 40/402; loss: 71.9855955209255; time: 4.5sec.
# batch: 50/402; loss: 3.756327314197416; time: 4.5sec.
# batch: 60/402; loss: 5.3972704175903115; time: 4.5sec.
# batch: 70/402; loss: 2.647720603661776; time: 4.6sec.
# batch: 80/402; loss: 10.725964720331309; time: 4.6sec.
# batch: 90/402; loss: 3.050210738486748; time: 4.5sec.
# batch: 100/402; loss: 6.719269126970237; time: 4.6sec.
# batch: 110/402; loss: 69.44976798667693; time: 4.6sec.
# batch: 120/402; loss: 65.22506972322965; time: 4.5sec.
# batch: 130/402; loss: 1063.979465287187; time: 4.6sec.
# batch: 140/402; loss: 14.529921336116022; time: 4.6sec.
# batch: 150/402; loss: 69.32455380222937; time: 4.3sec.
# batch: 160/402; loss: 1260.1616252370866; time: 4.8sec.
# batch: 170/402; loss: 3.610158900781785; time: 4.5sec.
# batch: 180/402; loss: 1065.0574265536611; time: 4.5sec.
# batch: 190/402; loss: 7.627004726486783; time: 4.4sec.
# batch: 200/402; loss: 131.48150214910288; time: 5.2sec.
# batch: 210/402; loss: 65.98522298332969; time: 4.4sec.
# batch: 220/402; loss: 251.84652581043792; time: 4.7sec.
# batch: 230/402; loss: 2.754571503039887; time: 4.2sec.
# batch: 240/402; loss: 1.786848419343761; time: 4.3sec.
# batch: 250/402; loss: 504.91775966742716; time: 4.4sec.
# batch: 260/402; loss: 2.4010227176415335; time: 4.2sec.
# batch: 270/402; loss: 14.447555781189275; time: 4.4sec.
# batch: 280/402; loss: 2.8643994694914423; time: 4.2sec.
# batch: 290/402; loss: 6.503138439404384; time: 4.4sec.
# batch: 300/402; loss: 64.77504219123624; time: 4.2sec.
# batch: 310/402; loss: 3.5162514454983103; time: 4.2sec.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3c15c5c58e01> in <module>
#      20         loss = ((dqn(X)[list(zip(*A))] - Y)**2).mean()
#      21
# ---> 22         loss.backward()
#      23         optimizer.step()
#      24
#
# ~/anaconda3/envs/gym/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/anaconda3/envs/gym/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
vid = create_episode_video(dqn)
ipd.HTML(vid.to_html5_video())
# Out:
# 100%|██████████| 437/437 [00:00<00:00, 666.79it/s]
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
envs = []
envs.append(gym.make("MsPacman-v0"))
envs.append(gym.make("MsPacman-v0"))

# %%
states_t = []

for i in range(len(envs)):
    states_t.append(preprocess_observation(envs[i].reset()))
    
are_t1_terminals = [False for i in range(len(states_t))]

# %%
states_t = torch.tensor(np.vstack(states_t))
Qs = dqn(states_t).detach().numpy()

# %%
Qs

# %%
np.argmax(Qs, axis=1)

# %%
actions = np.random.randint(0, 9, size=(len(Qs)))
actions

# %%
Qs = dqn(states).detach().numpy()
if greedy or np.random.rand()>epsilon:
    actions = np.argmax(Qs, axis=1)
else:
    actions = np.random.randint(0, action_space_size)

return action

# %%
while not all(are_t1_terminals):
    for i in range(len(envs)):
        action_t = choose_epsilon_greedy_action(state_t, self.dqn, epsilon=self.epsilon)

# %%
buffer = []
episodes = 0

for k in range(self.n_episodes):
    if self.verbose:
        print(f"start building buffer's episode # {episodes+1}...")

    cumulative_reward = 0.

    state_t = preprocess_observation(env.reset())
    is_t1_terminal = False

    while is_t1_terminal==False:
        action_t = choose_epsilon_greedy_action(state_t, self.dqn, epsilon=self.epsilon)

        state_t1, reward_t1, is_t1_terminal, info = env.step(action_t)
        cumulative_reward += reward_t1
        state_t1 = preprocess_observation(state_t1)

        buffer.append((state_t[0], action_t, reward_t1, state_t1[0], is_t1_terminal))
        state_t = state_t1

        if is_t1_terminal:
            if self.verbose:
                print(f"finished building buffer's episode # {episodes+1}. buffer length: {len(buffer)} steps. cumulative_reward={cumulative_reward}")
            episodes += 1
            gc.collect()

# %%
class BufferDataset(Dataset):
    """Face Landmarks dataset."""

    def __init__(self, dqn, n_episodes, discount, verbose=True, epsilon=0.1):
        """
        Args:
            buffer (list): list of tuples, where each tuple is (state_t, action_t, reward_t1, state_t1, is_t1_terminal).
        """
        self.n_episodes = n_episodes
        self.dqn = copy.deepcopy(dqn)
        self.discount = discount
        self.verbose = verbose
        self.epsilon = epsilon
        
        self.buffer = self._create_buffer()
        
        self.S_ts = [i[0] for i in self.buffer]
        self.As = np.array([j[1] for j in self.buffer])
        self.Qs_t1 = self._get_Qs_t1()
        self.Qs_t1_max = self.Qs_t1.max(axis=1)[0]
        self.Rs_t1 = torch.tensor(np.array([i[2] for i in self.buffer]))
        self.are_terminal_t1s = torch.tensor(np.array([i[4] for i in self.buffer]))

        self.ys = self.Rs_t1 + self.discount*self.are_terminal_t1s*self.Qs_t1_max
        
        if verbose:
            print(f"len(buffer): {len(self.buffer)}")
            print(f"Qs_t1.shape: {self.Qs_t1.shape}")
            print(f"Qs_t1_max.shape: {self.Qs_t1_max.shape}")
            print(f"Rs_t1.shape: {self.Rs_t1.shape}")
            print(f"are_terminal_t1s.shape: {self.are_terminal_t1s.shape}")
            
            print(f"ys.shape: {self.ys.shape}")
    
    def _create_buffer(self):
        buffer = []
        episodes = 0

        for k in range(self.n_episodes):
            if self.verbose:
                print(f"start building buffer's episode # {episodes+1}...")
                
            cumulative_reward = 0.
                    
            state_t = preprocess_observation(env.reset())
            is_t1_terminal = False
            
            while is_t1_terminal==False:
                action_t = choose_epsilon_greedy_action(state_t, self.dqn, epsilon=self.epsilon)

                state_t1, reward_t1, is_t1_terminal, info = env.step(action_t)
                cumulative_reward += reward_t1
                state_t1 = preprocess_observation(state_t1)

                buffer.append((state_t[0], action_t, reward_t1, state_t1[0], is_t1_terminal))
                state_t = state_t1
            
                if is_t1_terminal:
                    if self.verbose:
                        print(f"finished building buffer's episode # {episodes+1}. buffer length: {len(buffer)} steps. cumulative_reward={cumulative_reward}")
                    episodes += 1
                    gc.collect()
                    
        return buffer

    def _get_Qs_t1(self, batch_size=64):
        i=0
        Qs_t1 = []
        k=3 # the index of state_t1 in buffer sample.
        while i*batch_size<len(self.buffer):
            if self.verbose and (i*batch_size)%1000==0:
                print(f"preprocess Qs_t1: passed buffer[{(1000*(i*batch_size)//1000)}]")
            states_t1 = torch.stack([i[k] for i in self.buffer[i*batch_size:(i+1)*batch_size]])
            Qs_t1.append(self.dqn(states_t1).detach())
            gc.collect()
            i+=1

        return torch.cat(Qs_t1)
    
    
    def __len__(self):
        return len(self.buffer)

    def __getitem__(self, idx):
        X = self.S_ts[idx]
        A = self.As[idx]
        Y = self.ys[idx]
        
        return X, A, Y
